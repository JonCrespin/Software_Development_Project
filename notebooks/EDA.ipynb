# %%
import pandas as pd 
import numpy as np
import streamlit as st
import plotly.express as px

# %%
df= pd.read_csv('../vgchartz_2024.csv')

# %%
df.info() 
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64016 entries, 0 to 64015
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   img           64016 non-null  object
#  1   title         64016 non-null  object
#  2   console       64016 non-null  object
#  3   genre         64016 non-null  object
#  4   publisher     64016 non-null  object
#  5   developer     63999 non-null  object
#  6   critic_score  6678 non-null   float64
#  7   total_sales   18922 non-null  float64
#  8   na_sales      12637 non-null  float64
#  9   jp_sales      6726 non-null   float64
#  10  pal_sales     12824 non-null  float64
#  11  other_sales   15128 non-null  float64
#  12  release_date  56965 non-null  object
#  13  last_update   17879 non-null  object
# dtypes: float64(6), object(8)
# memory usage: 6.8+ MB
#                                              img                        title  \
# ...

# %%
df= df.drop(df.columns[0], axis =1)
df.info() 
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5362 entries, 1 to 64013
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         5362 non-null   object
#  1   console       5362 non-null   object
#  2   genre         5362 non-null   object
#  3   publisher     5362 non-null   object
#  4   developer     5362 non-null   object
#  5   critic_score  5362 non-null   float64
#  6   total_sales   5362 non-null   float64
#  7   na_sales      5362 non-null   float64
#  8   jp_sales      5362 non-null   float64
#  9   pal_sales     5362 non-null   float64
#  10  other_sales   5362 non-null   float64
#  11  release_date  5362 non-null   datetime64[ns]
#  12  last_update   5362 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(6), object(5)
# memory usage: 586.5+ KB
#                          title console             genre       publisher  \
# ...

# %%
df['release_date'] = pd.to_datetime(df['release_date'], format='%Y-%m-%d', errors='coerce')
print(df['release_date'].head())
# Out:
# 1    2014-11-18
# 7    2018-10-26
# 8    2012-11-13
# 9    2012-11-13
# 15   2017-09-29
# Name: release_date, dtype: datetime64[ns]

# %%
df = df.dropna(subset=['release_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5362 entries, 1 to 64013
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   img           5362 non-null   object
#  1   title         5362 non-null   object
#  2   console       5362 non-null   object
#  3   genre         5362 non-null   object
#  4   publisher     5362 non-null   object
#  5   developer     5360 non-null   object
#  6   critic_score  5362 non-null   float64
#  7   total_sales   5362 non-null   float64
#  8   na_sales      5362 non-null   float64
#  9   jp_sales      5362 non-null   float64
#  10  pal_sales     5362 non-null   float64
#  11  other_sales   5362 non-null   float64
#  12  release_date  5362 non-null   datetime64[ns]
#  13  last_update   5362 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(6), object(6)
# memory usage: 628.4+ KB

# %%
df['last_update'] = pd.to_datetime(df['last_update'], format='%Y-%m-%d', errors='coerce')
print(df['last_update'].head())
# Out:
# 1    2018-03-01
# 7    2018-02-11
# 8    2018-07-04
# 9    2018-07-04
# 15   2018-02-04
# Name: last_update, dtype: datetime64[ns]

# %%
df = df.dropna(subset=['last_update'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5362 entries, 1 to 64013
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   img           5362 non-null   object
#  1   title         5362 non-null   object
#  2   console       5362 non-null   object
#  3   genre         5362 non-null   object
#  4   publisher     5362 non-null   object
#  5   developer     5360 non-null   object
#  6   critic_score  5362 non-null   float64
#  7   total_sales   5362 non-null   float64
#  8   na_sales      5362 non-null   float64
#  9   jp_sales      5362 non-null   float64
#  10  pal_sales     5362 non-null   float64
#  11  other_sales   5362 non-null   float64
#  12  release_date  5362 non-null   datetime64[ns]
#  13  last_update   5362 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(6), object(6)
# memory usage: 628.4+ KB

# %%
df['total_sales'] = df['total_sales'].fillna(0)
df['na_sales'] = df['na_sales'].fillna(0)
df['jp_sales'] = df['jp_sales'].fillna(0)
df['pal_sales'] = df['pal_sales'].fillna(0)
df['other_sales'] = df['other_sales'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5362 entries, 1 to 64013
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   img           5362 non-null   object
#  1   title         5362 non-null   object
#  2   console       5362 non-null   object
#  3   genre         5362 non-null   object
#  4   publisher     5362 non-null   object
#  5   developer     5360 non-null   object
#  6   critic_score  5362 non-null   float64
#  7   total_sales   5362 non-null   float64
#  8   na_sales      5362 non-null   float64
#  9   jp_sales      5362 non-null   float64
#  10  pal_sales     5362 non-null   float64
#  11  other_sales   5362 non-null   float64
#  12  release_date  5362 non-null   datetime64[ns]
#  13  last_update   5362 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(6), object(6)
# memory usage: 628.4+ KB

# %%
median_critic_score = df['critic_score'].median()
df['critic_score'] = df['critic_score'].fillna(median_critic_score)
print(df['critic_score'].median())
# Out:
# 8.0

# %%
df.info() 
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5362 entries, 1 to 64013
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   img           5362 non-null   object
#  1   title         5362 non-null   object
#  2   console       5362 non-null   object
#  3   genre         5362 non-null   object
#  4   publisher     5362 non-null   object
#  5   developer     5360 non-null   object
#  6   critic_score  5362 non-null   float64
#  7   total_sales   5362 non-null   float64
#  8   na_sales      5362 non-null   float64
#  9   jp_sales      5362 non-null   float64
#  10  pal_sales     5362 non-null   float64
#  11  other_sales   5362 non-null   float64
#  12  release_date  5362 non-null   datetime64[ns]
#  13  last_update   5362 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(6), object(6)
# memory usage: 628.4+ KB
#                                               img                       title  \
# ...

# %%
missing_developers = df[df['developer'].isna()]
print(missing_developers[['title', 'console']])
# Out:
#                  title console
# 55431  My Friend Pedro      NS
# 55432  My Friend Pedro      PC

# %%
df.loc[(df['title'] == 'My Friend Pedro') & (df['console'].isin(['NS', 'PC'])), 'developer'] = 'DeadToast Entertainment'
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5362 entries, 1 to 64013
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   img           5362 non-null   object
#  1   title         5362 non-null   object
#  2   console       5362 non-null   object
#  3   genre         5362 non-null   object
#  4   publisher     5362 non-null   object
#  5   developer     5362 non-null   object
#  6   critic_score  5362 non-null   float64
#  7   total_sales   5362 non-null   float64
#  8   na_sales      5362 non-null   float64
#  9   jp_sales      5362 non-null   float64
#  10  pal_sales     5362 non-null   float64
#  11  other_sales   5362 non-null   float64
#  12  release_date  5362 non-null   datetime64[ns]
#  13  last_update   5362 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(6), object(6)
# memory usage: 628.4+ KB
